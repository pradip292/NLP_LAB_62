# %%
#(1) PREPARE DATASET
import pandas as pd
pd.set_option('display.max_colwidth', None)
file_url='https://archive.org/download/nltk-corpora/tweets.20150430-223406.tweet.tokenized.stemmed.lemmatized.csv'
df_initial = pd.read_csv(file_url,usecols=['id','text','posttoken'],encoding='utf-8')
print(df_initial.info())
df_initial.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10416 entries, 0 to 10415
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         10416 non-null  int64
#  1   text       10416 non-null  object
#  2   posttoken  10416 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 244.3+ KB
# None
#                    id  \
# 0  593891099434983425
# 1  593891099548094465
# 2  593891100429045760
# 3  593891101154619392
# 4  593891101838340096
#
#                                                                                                                                            text  \
# 0            RT @KirkKus: Indirect cost of the UK being in the EU is estimated to be costing Britain £170 billion per year! #BetterOffOut #UKIP
# 1                                                                                 VIDEO: Sturgeon on post-election deals http://t.co/BTJwrpbmOY
# 2                               RT @GregLauder: the UKIP east lothian candidate looks about 16 and still has an msn addy http://t.co/7eIU0c5Fm1
# 3                      RT @joannetallis: Ed Milliband is an embarrassment. Would you want him representing the UK?!  #bbcqt vote @Conservatives
# 4  RT @NivenJ1: “@George_Osborne: Ed Miliband proved tonight why he's not up to the job” Tbf you've spent 5 years doing that you salivating do…
#
#                                                                                                                                                                   posttoken
# 0     ['indirect', 'cost', 'of', 'the', 'uk', 'be', 'in', 'the', 'eu', 'be', 'estimate', 'to', 'be', 'cost', 'britain', 'billion', 'per', 'year', '#betteroffout', '#ukip']
# 1                                                                                                                               ['sturgeon', 'on', 'post-election', 'deal']
# 2                                                             ['the', 'ukip', 'east', 'lothian', 'candidate', 'look', 'about', 'and', 'still', 'have', 'an', 'msn', 'addy']
# 3                                               ['ed', 'milliband', 'be', 'an', 'embarrassment', 'would', 'you', 'want', 'him', 'represent', 'the', 'uk', '#bbcqt', 'vote']
# 4  ['ed', 'miliband', 'prove', 'tonight', 'why', 'he', 'be', 'not', 'up', 'to', 'the', 'job', 'tbf', 'you', 'have', 'spend', 'year', 'do', 'that', 'you', 'salivate', 'do']

# %%
#make a copy of initial df
df=df_initial.copy()
df
# Out:
#                        id  \
# 0      593891099434983425
# 1      593891099548094465
# 2      593891100429045760
# 3      593891101154619392
# 4      593891101838340096
# ...                   ...
# 10411  593908766166425600
# 10412  593908766829125632
# 10413  593908767378530306
# 10414  593908767537930240
# 10415  593908767454015490
#
#                                                                                                                                                 text  \
# 0                 RT @KirkKus: Indirect cost of the UK being in the EU is estimated to be costing Britain £170 billion per year! #BetterOffOut #UKIP
# 1                                                                                      VIDEO: Sturgeon on post-election deals http://t.co/BTJwrpbmOY
# 2                                    RT @GregLauder: the UKIP east lothian candidate looks about 16 and still has an msn addy http://t.co/7eIU0c5Fm1
# 3                           RT @joannetallis: Ed Milliband is an embarrassment. Would you want him representing the UK?!  #bbcqt vote @Conservatives
# 4       RT @NivenJ1: “@George_Osborne: Ed Miliband proved tonight why he's not up to the job” Tbf you've spent 5 years doing that you salivating do…
# ...                                                                                                                                              ...
# 10411  RT @UKLabour: .@Ed_Miliband: we're not going to do a deal with the SNP, there will be no coalition with the SNP. #bbcqt\nhttps://t.co/n65hTe…
# 10412   RT @DisabledScot: @blairmcdougall @ScotlandTonight @bbcqt If Ed thinks Scots will suddenly rush to vote Labour, we'll vote SNP, Labour just…
# 10413   RT @Staircase2: @VividRicky exactly but that alleged commute was made up by Farage as was his 'discomfort' in allegedly 'not hearing Englis…
# 10414                                                                                Actually agreed with %95 of what farage was sayin rhen#voteukip
# 10415   RT @PeatWorrier: "A vote for the SNP is. Er. A vote for another referendum we insist Holyrood has no legal authority to legislate for" http…
#
#                                                                                                                                                                                    posttoken
# 0                      ['indirect', 'cost', 'of', 'the', 'uk', 'be', 'in', 'the', 'eu', 'be', 'estimate', 'to', 'be', 'cost', 'britain', 'billion', 'per', 'year', '#betteroffout', '#ukip']
# 1                                                                                                                                                ['sturgeon', 'on', 'post-election', 'deal']
# 2                                                                              ['the', 'ukip', 'east', 'lothian', 'candidate', 'look', 'about', 'and', 'still', 'have', 'an', 'msn', 'addy']
# 3                                                                ['ed', 'milliband', 'be', 'an', 'embarrassment', 'would', 'you', 'want', 'him', 'represent', 'the', 'uk', '#bbcqt', 'vote']
# 4                   ['ed', 'miliband', 'prove', 'tonight', 'why', 'he', 'be', 'not', 'up', 'to', 'the', 'job', 'tbf', 'you', 'have', 'spend', 'year', 'do', 'that', 'you', 'salivate', 'do']
# ...                                                                                                                                                                                      ...
# 10411                                     ['we', 'be', 'not', 'go', 'to', 'do', 'a', 'deal', 'with', 'the', 'snp', 'there', 'will', 'be', 'no', 'coalition', 'with', 'the', 'snp', '#bbcqt']
# 10412                                                       ['if', 'ed', 'think', 'scot', 'will', 'suddenly', 'rush', 'to', 'vote', 'labour', 'we', 'will', 'vote', 'snp', 'labour', 'just']
# 10413                       ['exactly', 'but', 'that', 'allege', 'commute', 'be', 'make', 'up', 'by', 'farage', 'as', 'be', 'his', 'discomfort', 'in', 'allegedly', 'not', 'hear', 'englis']
# 10414                                                                                              ['actually', 'agree', 'with', 'of', 'what', 'farage', 'be', 'sayin', 'rhen', '#voteukip']
# 10415  ['a', 'vote', 'for', 'the', 'snp', 'be', 'er', 'a', 'vote', 'for', 'another', 'referendum', 'we', 'insist', 'holyrood', 'have', 'no', 'legal', 'authority', 'to', 'legislate', 'for']
#
# [10416 rows x 3 columns]
